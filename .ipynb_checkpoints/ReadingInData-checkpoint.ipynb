# %% [markdown]
# ## Playing with Geopandas
# - I'm using Python3 for this, which for some reason works
# - I have to open this notebook via Anaconda Lancher, using the environment I created containing geopandas

# %%
import pandas as pd
import geopandas as gp
import matplotlib.pyplot as plt
# %matplotlib inline
pd.options.display.max_rows = 10

# %% [markdown]
# __Step 1.__ Get a sense of the shape file, _precincts.shp_, and put the data into _map_data_

# %%
map_data = gp.read_file("precincts.shp")

# %%
map_data.columns
# Out:
# Index(['DP', 'DPnum', 'DPtype', 'County', 'ZEROPOP', 'BallotType', 'US_House',
#        'State_Hous', 'State_Sena', 'County_Cou', 'Shape_Leng', 'Shape_Area',
#        'geometry'],
#       dtype='object')

# %%
map_data.head()
# Out:
#       DP  DPnum DPtype  County ZEROPOP       BallotType US_House State_Hous  \
# 0  07-03    703     PP  HAWAII    None  CD2-H07-S04-CC9      CD2         H7
# 1  01-05    105     PP  HAWAII    None  CD2-H01-S04-CC1      CD2         H1
# 2  01-01    101     PP  HAWAII    None  CD2-H01-S04-CC1      CD2         H1
# 3  01-02    102     PP  HAWAII    None  CD2-H01-S04-CC1      CD2         H1
# 4  01-06    106     PP  HAWAII    None  CD2-H01-S04-CC1      CD2         H1
#
#   State_Sena County_Cou     Shape_Leng    Shape_Area  \
# 0         S4        CC9  100748.260922  3.433163e+08
# 1         S4        CC1   75515.354158  1.434849e+08
# 2         S4        CC1  141411.346571  3.771898e+08
# 3         S4        CC1   69022.641881  2.207124e+08
# 4         S4        CC1   72825.893157  1.087545e+08
#
#                                             geometry
# 0  POLYGON ((835411.3768999996 2242169.546499999,...
# 1  POLYGON ((906512.0015000002 2203194.6965, 9065...
# ...

# %%
map_data.geometry.area
# Out:
# 0      3.433163e+08
# 1      1.434849e+08
# 2      3.771898e+08
# 3      2.207124e+08
# 4      1.087545e+08
#            ...
# 257    2.211896e+07
# 258    2.262533e+06
# 259    9.746181e+07
# 260    3.349697e+06
# 261    4.727726e+06
# Length: 262, dtype: float64

# %% [markdown]
# __Step 2.__ Plot the map

# %%
fig, ax = plt.subplots(figsize=(12,10), subplot_kw={'aspect':'equal'})
data.plot(column='County', legend=True, ax=ax)

# %%
map_data.geometry.area.hist(bins=50)

# %%
bounds = map_data.bounds
bounds
# Out:
#             minx          miny         maxx          maxy
# 0    823535.0310  2.220221e+06  844965.6632  2.244326e+06
# 1    883987.9895  2.193798e+06  910533.7425  2.205202e+06
# 2    843597.0721  2.203773e+06  875547.5763  2.235551e+06
# 3    870653.0280  2.199418e+06  885484.0439  2.224070e+06
# 4    883985.8895  2.189295e+06  910230.9682  2.196796e+06
# ..           ...           ...          ...           ...
# 257  622847.1316  2.359363e+06  630981.3063  2.365290e+06
# 258  628667.0265  2.363384e+06  630925.4508  2.366091e+06
# 259  590911.2275  2.379629e+06  602845.5024  2.393353e+06
# 260  598698.9478  2.357789e+06  601810.4958  2.360009e+06
# 261  594289.3009  2.358148e+06  598132.6944  2.360297e+06
#
# [262 rows x 4 columns]

# %%
# get a subset of OAHU

map_oahu = data[data['County']=='OAHU']
map_oahu.head()
# Out:
#         DP  DPnum DPtype County ZEROPOP       BallotType US_House State_Hous  \
# 102  17-01   1701     PP   OAHU    None  CD1-H17-S25-CC4      CD1        H17
# 103  17-02   1702     PP   OAHU    None  CD1-H17-S25-CC4      CD1        H17
# 104  17-03   1703     PP   OAHU    None  CD1-H17-S09-CC4      CD1        H17
# 105  17-04   1704     PP   OAHU    None  CD1-H17-S09-CC4      CD1        H17
# 106  19-01   1901     PP   OAHU    None  CD1-H19-S09-CC4      CD1        H19
#
#     State_Sena County_Cou    Shape_Leng    Shape_Area  \
# 102        S25        CC4  21556.712202  7.769463e+06
# 103        S25        CC4  14253.484569  4.166595e+06
# 104         S9        CC4  16964.251950  9.118685e+06
# 105         S9        CC4  10326.833881  4.819473e+06
# 106         S9        CC4  21925.535906  6.397481e+06
#
#                                               geometry
# 102  POLYGON ((640118.2456 2356929.160700001, 64012...
# 103  POLYGON ((635133.0470000003 2354599.646600001,...
# ...

# %% [markdown]
# __Step 3.__ Try open the election result files, _statewideprecinctdetail.txt_, and _summary.txt_
# Then, explore these files to see if any columns can be merged into the shp file

# %%
df_det = pd.read_csv('statewideprecintdetail.txt',skiprows=0)

# %%
df_det.head()
# Out:
#   Precinct_Name  Split_Name  precinct_splitId  Reg_voters  Ballots  Reporting  \
# 0         01-01         NaN                 1        2863     1067          1
# 1         01-01         NaN                 1        2863     1067          1
# 2         01-01         NaN                 1        2863     1067          1
# 3         01-01         NaN                 1        2863     1067          1
# 4         01-01         NaN                 1        2863     1067          1
#
#    Contest_id     Contest_title  Contest_party  Choice_id  \
# 0           2  U.S. Senator - D            NaN          7
# 1           3  U.S. Senator - N            NaN          8
# 2           3  U.S. Senator - N            NaN          9
# 3           3  U.S. Senator - N            NaN         10
# 4           4  U.S. Senator - R            NaN         11
#
#                Candidate_name  Choice_party Candidate_Type  Absentee_votes  \
# ...

# %%
df_summ = pd.read_csv('summary.txt')
df_summ.head()
# Out:
#    Contest ID     Contest Title  Contest Seq Nbr Contest Type  Contest Party  \
# 0           2  U.S. Senator - D                2           OF            NaN
# 1           3  U.S. Senator - N                3           OF            NaN
# 2           3  U.S. Senator - N                3           OF            NaN
# 3           3  U.S. Senator - N                3           OF            NaN
# 4           4  U.S. Senator - R                4           OF            NaN
#
#    Absentee Mail Blank Votes  Absentee Walk-in Blank Votes  \
# 0                      24424                          3164
# 1                        599                            42
# 2                        599                            42
# 3                        599                            42
# 4                       3197                           309
#
#    Election Blank Votes  Absentee Mail Over Votes  \
# 0                 18565                        99
# ...

# %% [markdown]
# See if any of the column names match, between the __map_data__ and the __df__'s

# %%
map_data.columns
# Out:
# Index(['DP', 'DPnum', 'DPtype', 'County', 'ZEROPOP', 'BallotType', 'US_House',
#        'State_Hous', 'State_Sena', 'County_Cou', 'Shape_Leng', 'Shape_Area',
#        'geometry'],
#       dtype='object')

# %%
df_det.columns
# Out:
# Index(['Precinct_Name', 'Split_Name', 'precinct_splitId', 'Reg_voters',
#        'Ballots', 'Reporting', 'Contest_id', 'Contest_title', 'Contest_party',
#        'Choice_id', 'Candidate_name', 'Choice_party', 'Candidate_Type',
#        'Absentee_votes', 'Early_votes', 'Election_Votes'],
#       dtype='object')

# %%
# See if there's any match

match = [each for each in data.columns if each in df.columns]
match
# Out:
# []

# %%
# See if there's any match

match = [each for each in map_data.columns if each in df_summ.columns]
match
# Out:
# []

# %% [markdown]
# Ok, so there's no match of column names... :disappointed:
